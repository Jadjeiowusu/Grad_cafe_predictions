# %%
link = 'https://raw.githubusercontent.com/deedy/gradcafe_data/master/all/all_clean.csv'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(link, header = None)
df.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    0                                        1                             2   \
# 0   0  University Of Southern California (USC)        Ms. Green Technologies
# 1   1                    Vanderbilt University  Education: Special Education
# 2   2                 University Of Pittsburgh                  Public Heath
# 3   3                         Tufts University              Computer Science
# 4   4                  University Of Edinburgh           Theoretical Physics
#
#     3    4         5        6               7             8    9      10  \
# 0   MS  S16  Accepted   E-mail   (5, 11, 2015)  1.446700e+09  NaN    NaN
# 1   MS  F16     Other    Other             NaN           NaN  NaN    NaN
# ...

# %%
col = ['rowid', 'uni_name', 'major', 'degree', 'season', 'decision','decision_method','decision_date','decision_timestamp','ugrad_gpa',
       'gre_verbal','gre_quant', 'gre_writing', 'is_new_gre', 'gre_subject','status','post_date','post_timestamp', 'comments']

# %%
df.columns = col
df.head()
# Out:
#    rowid                                 uni_name  \
# 0      0  University Of Southern California (USC)
# 1      1                    Vanderbilt University
# 2      2                 University Of Pittsburgh
# 3      3                         Tufts University
# 4      4                  University Of Edinburgh
#
#                           major degree season  decision decision_method  \
# 0        Ms. Green Technologies     MS    S16  Accepted          E-mail
# 1  Education: Special Education     MS    F16     Other           Other
# 2                  Public Heath     MS    F16  Accepted          E-mail
# 3              Computer Science    PhD    S16  Accepted          E-mail
# 4           Theoretical Physics     MS    F16  Accepted         Website
#
#     decision_date  decision_timestamp  ugrad_gpa  gre_verbal  gre_quant  \
# 0   (5, 11, 2015)        1.446700e+09        NaN         NaN        NaN
# 1             NaN                 NaN        NaN         NaN        NaN
# ...

# %%
df.dropna(axis =0, inplace= True)
df.head()
# Out:
#      rowid                                      uni_name  \
# 399    399                           Stanford University
# 400    400                          Princeton University
# 401    401    University Of California, San Diego (UCSD)
# 402    402  University Of California, Los Angeles (UCLA)
# 403    403              University Of Chicago (UChicago)
#
#                                                  major degree season  \
# 399            Biosciences (Biology And Neurosciences)    PhD    F15
# 400                                  Molecular Biology    PhD    F15
# 401                                Biomedical Sciences    PhD    F15
# 402  Molecular Biology / Cell And Developmental Bio...    PhD    F15
# 403  Molecular Biosciences - Cell And Molecular Bio...    PhD    F15
#
#      decision decision_method  decision_date  decision_timestamp  ugrad_gpa  \
# 399  Rejected  Postal Service  (10, 2, 2015)        1.423544e+09       3.55
# ...

# %%
df.columns
# Out:
# Index(['rowid', 'uni_name', 'major', 'degree', 'season', 'decision',
#        'decision_method', 'decision_date', 'decision_timestamp', 'ugrad_gpa',
#        'gre_verbal', 'gre_quant', 'gre_writing', 'is_new_gre', 'gre_subject',
#        'status', 'post_date', 'post_timestamp', 'comments'],
#       dtype='object')

# %%
df['uni_name'].unique()

# %%
sel = ['Stanford University', 'University Of California, San Diego (UCSD)','University Of California, Los Angeles (UCLA)',
'Harvard University','Carnegie Mellon University (CMU)','University Of Michigan, Ann Arbor (UMich)', 'Yale University',
'University Of California, Berkeley (UCB)', 'University Of Alberta', 'Cornell University']

# %%
df1 = df[df['uni_name'].isin(sel)]
df1.head()
# Out:
#       rowid                                      uni_name  \
# 399     399                           Stanford University
# 401     401    University Of California, San Diego (UCSD)
# 402     402  University Of California, Los Angeles (UCLA)
# 407     407                            Harvard University
# 3980   3980              Carnegie Mellon University (CMU)
#
#                                                   major degree season  \
# 399             Biosciences (Biology And Neurosciences)    PhD    F15
# 401                                 Biomedical Sciences    PhD    F15
# 402   Molecular Biology / Cell And Developmental Bio...    PhD    F15
# 407                                                 BBS    PhD    F15
# 3980                                            Physics    PhD    F15
#
#       decision decision_method  decision_date  decision_timestamp  ugrad_gpa  \
# 399   Rejected  Postal Service  (10, 2, 2015)        1.423544e+09       3.55
# ...

# %%
df1.columns
# Out:
# Index(['rowid', 'uni_name', 'major', 'degree', 'season', 'decision',
#        'decision_method', 'decision_date', 'decision_timestamp', 'ugrad_gpa',
#        'gre_verbal', 'gre_quant', 'gre_writing', 'is_new_gre', 'gre_subject',
#        'status', 'post_date', 'post_timestamp', 'comments'],
#       dtype='object')

# %%
rem = ['rowid', 'decision_method', 'decision_date', 'decision_timestamp', 'is_new_gre','post_date', 'post_timestamp', 'comments']

# %%
df1 = df1.drop(columns= rem)
df1.head()
# Out:
#                                           uni_name  \
# 399                            Stanford University
# 401     University Of California, San Diego (UCSD)
# 402   University Of California, Los Angeles (UCLA)
# 407                             Harvard University
# 3980              Carnegie Mellon University (CMU)
#
#                                                   major degree season  \
# 399             Biosciences (Biology And Neurosciences)    PhD    F15
# 401                                 Biomedical Sciences    PhD    F15
# 402   Molecular Biology / Cell And Developmental Bio...    PhD    F15
# 407                                                 BBS    PhD    F15
# 3980                                            Physics    PhD    F15
#
#       decision  ugrad_gpa  gre_verbal  gre_quant  gre_writing  gre_subject  \
# 399   Rejected       3.55       157.0      163.0          4.0        670.0
# 401   Rejected       3.55       157.0      163.0          4.0        670.0
# ...
